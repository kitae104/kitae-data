# %% [markdown]
# # 02 반도체 공정 데이터 분석 · 복습 빈칸 채우기 — 학생용
#
# 수업에서 배운 핵심 코드를 빈칸을 채우며 다시 익혀 봅니다.
#
# - 코드 안의 `___`를 알맞은 코드로 바꾼 뒤 셀을 실행하세요.
# - 막히면 **힌트**를, 실행한 뒤에는 **예상 결과**를 열어 내 결과와 비교하세요.
# - 위에서 아래로 순서대로 실행하세요. 앞 셀에서 만든 변수를 뒤 셀에서 사용하므로, 앞 빈칸을 채워야 다음 셀이 실행됩니다.
# - `반도체_공정_샘플.csv`가 이 노트북과 같은 폴더에 있어야 합니다.

# %% [markdown]
# ## 1단계 · 라이브러리 불러오기
#
# 모든 분석의 시작입니다. 이 셀을 채워야 아래 셀이 실행됩니다.

# %% [markdown]
# ### Q1. 라이브러리를 별칭으로 불러오기
#
# pandas, numpy, matplotlib, seaborn을 수업에서 쓴 짧은 이름으로 불러옵니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# 수업에서 쓴 별칭: pandas → `pd`, numpy → `np`, matplotlib.pyplot → `plt`, seaborn → `sns`
#
# </details>

# %%
import pandas as ___
import numpy as ___
import matplotlib.pyplot as ___
import seaborn as ___

plt.rcParams['font.family'] = 'Malgun Gothic'  # 한글 표시 (Mac: 'AppleGothic')
plt.rcParams['axes.unicode_minus'] = False       # 음수(-) 기호 깨짐 방지
print("✅ 라이브러리 준비 완료!")

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
# ✅ 라이브러리 준비 완료!
# ```
#
# </details>

# %% [markdown]
# ## 2단계 · 데이터 불러오기 & 탐색

# %% [markdown]
# ### Q2. CSV 파일 읽기
#
# CSV를 DataFrame으로 읽고 행 수와 열 수를 출력합니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# CSV를 읽는(read) 함수입니다. `shape`의 첫 번째 값은 행, 두 번째 값은 열입니다. (번호는 0부터)
#
# </details>

# %%
df = pd.___('반도체_공정_샘플.csv')
print(f"데이터 크기: {df.shape[___]}행 × {df.shape[___]}열")

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
# 데이터 크기: 200행 × 12열
# ```
#
# </details>

# %% [markdown]
# ### Q3. 처음 5줄 미리보기
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# 괄호 안을 비우면 기본 5줄입니다.
#
# </details>

# %%
df.___()

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
#                측정시간       온도_섭씨        압력_Pa  ...    처리시간_sec   냉각수온도_섭씨  합격여부
# 0  2024-03-01 17:00  302.483571  1011.617357  ...  117.652628  20.542560     1
# 1   2024-03-02 4:00  297.682911  1008.342702  ...  115.459880  18.587696     1
# 2  2024-03-02 18:00  307.328244  1010.742237  ...  116.996807  19.708306     1
# 3  2024-03-02 22:00  296.991467  1031.522782  ...  113.359070  20.196861     1
# 4   2024-03-03 0:00  301.620420  1009.149177  ...  121.656317  20.975545     1
#
# [5 rows x 12 columns]
# ```
#
# </details>

# %% [markdown]
# ### Q4. 전체 구조 요약 보기
#
# 열 이름, 자료형, 결측이 아닌 값의 개수를 봅니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# 정보(information)를 줄인 이름의 함수입니다.
#
# </details>

# %%
df.___()

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   측정시간       200 non-null    str
#  1   온도_섭씨      188 non-null    float64
#  2   압력_Pa      191 non-null    float64
#  3   가스유량_slm   193 non-null    float64
#  4   전력_W       190 non-null    float64
#  5   진공도_mTorr  191 non-null    float64
#  6   두께_nm      192 non-null    float64
#  7   습도_pct     187 non-null    float64
#  8   진동_mm_s    192 non-null    float64
#  9   처리시간_sec   190 non-null    float64
#  10  냉각수온도_섭씨   194 non-null    float64
#  11  합격여부       200 non-null    int64
# dtypes: float64(10), int64(1), str(1)
# memory usage: 18.9 KB
# ```
#
# </details>

# %% [markdown]
# ### Q5. 숫자 열의 기술 통계 보기
#
# 소수점 2자리로 반올림해서 봅니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# '묘사하다'라는 뜻의 함수입니다.
#
# </details>

# %%
df.___().round(2)

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
#         온도_섭씨    압력_Pa  가스유량_slm     전력_W  ...  진동_mm_s  처리시간_sec  냉각수온도_섭씨   합격여부
# count  188.00   191.00    193.00   190.00  ...   192.00    190.00    194.00  200.0
# mean   300.72  1012.98     50.15  2004.07  ...     0.50    120.11     20.14    0.8
# std      6.39    13.01      2.49    37.56  ...     0.05      4.68      1.04    0.6
# min    278.44   963.05     39.83  1934.04  ...     0.38    104.90     17.13   -1.0
# 25%    298.17  1006.60     48.72  1977.51  ...     0.47    117.25     19.43    1.0
# 50%    300.75  1012.63     50.12  2001.70  ...     0.50    120.28     20.10    1.0
# 75%    303.56  1021.01     51.46  2024.00  ...     0.53    122.98     20.85    1.0
# max    332.51  1059.72     63.20  2165.78  ...     0.62    135.39     23.85    1.0
#
# [8 rows x 11 columns]
# ```
#
# </details>

# %% [markdown]
# ### Q6. 여러 열 선택하기
#
# 온도, 압력, 합격여부 세 열만 봅니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# 열 이름 목록을 넣으므로 대괄호가 두 겹입니다.
#
# </details>

# %%
df[___]

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
#           온도_섭씨        압력_Pa  합격여부
# 0    302.483571  1011.617357     1
# 1    297.682911  1008.342702     1
# 2    307.328244  1010.742237     1
# 3    296.991467  1031.522782     1
# 4    301.620420  1009.149177     1
# ..          ...          ...   ...
# 195  304.035613  1059.724303    -1
# 196  278.441169  1017.496559    -1
# 197  305.294455   997.616300    -1
# 198  298.677426  1047.604336    -1
# 199  314.356966  1008.118030    -1
#
# [200 rows x 3 columns]
# ```
#
# </details>

# %% [markdown]
# ### Q7. 한 열의 평균과 최댓값 구하기
#
# 온도 열의 평균과 최고 온도를 출력합니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# 평균은 `mean()`, 최댓값은 `max()`입니다.
#
# </details>

# %%
print(f"평균 온도: {df['온도_섭씨'].___():.2f}°C")
print(f"최고 온도: {df['온도_섭씨'].___():.2f}°C")

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
# 평균 온도: 300.72°C
# 최고 온도: 332.51°C
# ```
#
# </details>

# %% [markdown]
# ### Q8. 위치(번호)로 행 선택하기
#
# 1~4번 행을 선택합니다. (5번 미포함)
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# 위치로 고를 때는 `iloc`입니다.
#
# </details>

# %%
df.___[1:5]

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
#                측정시간       온도_섭씨        압력_Pa  ...    처리시간_sec   냉각수온도_섭씨  합격여부
# 1   2024-03-02 4:00  297.682911  1008.342702  ...  115.459880  18.587696     1
# 2  2024-03-02 18:00  307.328244  1010.742237  ...  116.996807  19.708306     1
# 3  2024-03-02 22:00  296.991467  1031.522782  ...  113.359070  20.196861     1
# 4   2024-03-03 0:00  301.620420  1009.149177  ...  121.656317  20.975545     1
#
# [4 rows x 12 columns]
# ```
#
# </details>

# %% [markdown]
# ### Q9. 라벨로 행과 열 선택하기
#
# 0~4번 행의 온도와 합격여부를 선택합니다. (끝 번호 포함)
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# 이름(label)으로 고를 때는 `loc`입니다.
#
# </details>

# %%
df.___[0:4, ['온도_섭씨', '합격여부']]

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
#         온도_섭씨  합격여부
# 0  302.483571     1
# 1  297.682911     1
# 2  307.328244     1
# 3  296.991467     1
# 4  301.620420     1
# ```
#
# </details>

# %% [markdown]
# ### Q10. 값별 개수와 비율 세기
#
# 합격여부별 개수와 비율(%)을 봅니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# 값(value)을 세는(count) 함수입니다. 비율로 바꾸는 옵션은 '정규화'라는 뜻의 이름입니다.
#
# </details>

# %%
print(df['합격여부'].___())
print(df['합격여부'].value_counts(___=True) * 100)

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
# 합격여부
#  1    180
# -1     20
# Name: count, dtype: int64
# 합격여부
#  1    90.0
# -1    10.0
# Name: proportion, dtype: float64
# ```
#
# </details>

# %% [markdown]
# ## 3단계 · 결측값 & 중복 처리

# %% [markdown]
# ### Q11. 결측값 개수 세기
#
# 열별 결측값 개수와 전체 결측값 개수를 봅니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# 결측이면 True를 주는 함수 → `sum()`은 열별 합계, 한 번 더 `sum()`하면 전체 합계입니다.
#
# </details>

# %%
print(df.___().sum())
print(f"전체 결측값 개수: {df.isnull().sum().___()}개")

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
# 측정시간          0
# 온도_섭씨        12
# 압력_Pa         9
# 가스유량_slm      7
# 전력_W         10
# 진공도_mTorr     9
# 두께_nm         8
# 습도_pct       13
# 진동_mm_s       8
# 처리시간_sec     10
# 냉각수온도_섭씨      6
# 합격여부          0
# dtype: int64
# 전체 결측값 개수: 92개
# ```
#
# </details>

# %% [markdown]
# ### Q12. 결측값을 평균으로 채우기
#
# 원본은 두고 복사본의 숫자 열 결측값을 각 열의 평균으로 채웁니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# 복사는 `copy()`, 채우기는 `fillna()`, 평균은 `mean()`입니다.
#
# </details>

# %%
df_filled = df.___()
numeric_cols = ['온도_섭씨', '압력_Pa', '가스유량_slm', '전력_W',
                '진공도_mTorr', '두께_nm', '습도_pct', '진동_mm_s',
                '처리시간_sec', '냉각수온도_섭씨']

for col in numeric_cols:
    df_filled[col] = df_filled[col].___(df_filled[col].___())

print(f"처리 후 남은 결측값: {df_filled.isnull().sum().sum()}개")

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
# 처리 후 남은 결측값: 0개
# ```
#
# </details>

# %% [markdown]
# ### Q13. 중복 제거하고 인덱스 다시 매기기
#
# 중복 행 수를 확인하고, 제거한 뒤 인덱스를 0부터 다시 매깁니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# 중복 확인 `duplicated()` → 제거 `drop_duplicates()` → 인덱스 초기화 `reset_index()`
#
# </details>

# %%
print(f"중복 행 수: {df_filled.___().sum()}개")
df_clean = df_filled.___().___(drop=True)
print(f"정리 전: {len(df_filled)}행 → 정리 후: {len(df_clean)}행")

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
# 중복 행 수: 0개
# 정리 전: 200행 → 정리 후: 200행
# ```
#
# </details>

# %% [markdown]
# ## 4단계 · 탐색적 데이터 분석 (EDA)

# %% [markdown]
# ### Q14. 값을 바꿔 새 열 만들기
#
# 합격여부 1/-1을 '합격'/'불합격'으로 바꾼 result 열을 만듭니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# 딕셔너리로 값을 바꾸는 함수는 `map()`입니다.
#
# </details>

# %%
df_clean['result'] = df_clean['합격여부'].___({1: '합격', -1: '불합격'})
df_clean[['합격여부', 'result']].head()

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
#    합격여부 result
# 0     1     합격
# 1     1     합격
# 2     1     합격
# 3     1     합격
# 4     1     합격
# ```
#
# </details>

# %% [markdown]
# ### Q15. 불합격 데이터만 고르기
#
# 합격여부가 -1인 행만 골라 개수를 셉니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# '같다'를 뜻하는 비교 연산자는 `=`가 두 개입니다.
#
# </details>

# %%
fail_df = df_clean[df_clean['합격여부'] ___ -1]
print(f"불합격 건수: {len(fail_df)}건")

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
# 불합격 건수: 20건
# ```
#
# </details>

# %% [markdown]
# ### Q16. 여러 조건 함께 쓰기
#
# 온도가 305도를 넘고 두께가 103nm를 넘는 공정을 고릅니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# 두 조건을 모두 만족(AND)하는 기호입니다. 조건마다 괄호가 필요합니다.
#
# </details>

# %%
risk_df = df_clean[(df_clean['온도_섭씨'] > 305) ___ (df_clean['두께_nm'] > 103)]
print(f"고온+두꺼움 공정: {len(risk_df)}건")

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
# 고온+두꺼움 공정: 4건
# ```
#
# </details>

# %% [markdown]
# ### Q17. 합격/불합격별 평균 비교하기
#
# result별 숫자 열 평균을 구하고, 보기 편하게 행과 열을 뒤집어 출력합니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# 그룹으로 묶는 함수와, 행·열을 뒤집는 속성(Transpose)입니다.
#
# </details>

# %%
group_mean = df_clean.___('result')[numeric_cols].mean().round(2)
print(group_mean.___)

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
# result         불합격       합격
# 온도_섭씨       303.82   300.37
# 압력_Pa      1010.49  1013.26
# 가스유량_slm     51.13    50.04
# 전력_W       2029.46  2001.25
# 진공도_mTorr     5.50     5.03
# 두께_nm       104.42    99.97
# 습도_pct       44.65    44.87
# 진동_mm_s       0.50     0.50
# 처리시간_sec    118.00   120.35
# 냉각수온도_섭씨     19.90    20.17
# ```
#
# </details>

# %% [markdown]
# ### Q18. 히스토그램 그리기
#
# 온도 값이 어떻게 퍼져 있는지 봅니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# 히스토그램(histogram)을 줄인 이름의 함수입니다.
#
# </details>

# %%
plt.figure(figsize=(8, 4))
plt.___(df_clean['온도_섭씨'], bins=20, color='steelblue', edgecolor='white')
plt.title('온도 분포')
plt.xlabel('온도 (°C)')
plt.ylabel('빈도 (개수)')
plt.show()

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# 📊 그래프가 그려지면 성공입니다.
#
# </details>

# %% [markdown]
# ### Q19. 박스플롯으로 합격/불합격 비교하기
#
# seaborn으로 판정별 온도 분포를 비교합니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# seaborn의 상자(box) 그래프 함수입니다.
#
# </details>

# %%
plt.figure(figsize=(7, 5))
sns.___(data=df_clean, x='result', y='온도_섭씨',
            hue='result', legend=False,
            palette=['#52B788', '#E76F51'])
plt.title('판정별 온도 분포 비교')
plt.show()

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# 📊 그래프가 그려지면 성공입니다.
#
# </details>

# %% [markdown]
# ### Q20. 상관관계 히트맵 그리기
#
# 숫자 열과 합격여부 사이의 상관관계를 계산하고 색으로 봅니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# 상관관계(correlation)를 줄인 함수, 그리고 열지도(heatmap) 함수입니다.
#
# </details>

# %%
corr_matrix = df_clean[numeric_cols + ['합격여부']].___()

plt.figure(figsize=(11, 9))
sns.___(corr_matrix, annot=True, fmt='.2f', cmap='RdYlGn', center=0, linewidths=0.5)
plt.title('변수 간 상관관계')
plt.show()

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# 📊 그래프가 그려지면 성공입니다.
#
# </details>

# %% [markdown]
# ## 5 · 보강 실습

# %% [markdown]
# ### Q21. 결측률(%) 구하기
#
# 원본 df의 열별 결측 비율을 %로 보고, 큰 순서로 5개만 봅니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# True/False의 평균이 곧 비율입니다.
#
# </details>

# %%
missing_rate = df.isna().___() * 100
print(missing_rate.sort_values(ascending=False).head().round(2))

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
# 습도_pct      6.5
# 온도_섭씨       6.0
# 전력_W        5.0
# 처리시간_sec    5.0
# 압력_Pa       4.5
# dtype: float64
# ```
#
# </details>

# %% [markdown]
# ### Q22. IQR로 이상값 후보 찾기
#
# 온도의 Q1(25%), Q3(75%)로 일반 범위를 구하고, 범위를 벗어난 행을 셉니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# 분위수는 `quantile()`입니다. '작거나 또는 크거나'이므로 OR 기호를 씁니다.
#
# </details>

# %%
q1 = df_clean['온도_섭씨'].___(0.25)
q3 = df_clean['온도_섭씨'].quantile(___)
iqr = q3 - q1
lower = q1 - 1.5 * iqr
upper = q3 + 1.5 * iqr

outliers = df_clean[(df_clean['온도_섭씨'] < lower) ___ (df_clean['온도_섭씨'] > upper)]
print(f"온도 일반 범위: {lower:.2f} ~ {upper:.2f} °C")
print(f"이상값 후보: {len(outliers)}건")

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
# 온도 일반 범위: 291.14 ~ 310.57 °C
# 이상값 후보: 19건
# ```
#
# </details>

# %% [markdown]
# ### Q23. 평균 차이가 큰 변수 찾기
#
# 불합격 평균과 합격 평균의 차이를 절댓값으로 구해 큰 순서로 봅니다.
#
# <details>
# <summary><strong>💡 힌트</strong></summary>
#
# 절댓값 함수는 `abs()`입니다.
#
# </details>

# %%
result_means = df_clean.groupby('result')[numeric_cols].mean()
mean_gap = (result_means.loc['불합격'] - result_means.loc['합격']).___()
print(mean_gap.sort_values(ascending=False).head().round(3))

# %% [markdown]
# <details>
# <summary><strong>✅ 예상 결과</strong></summary>
#
# ```
# 전력_W        28.206
# 두께_nm        4.447
# 온도_섭씨        3.450
# 압력_Pa        2.770
# 처리시간_sec     2.344
# dtype: float64
# ```
#
# </details>

# %% [markdown]
# ## 마무리
#
# 모든 빈칸을 채워 끝까지 실행했다면 성공입니다. 틀린 빈칸은 강의 페이지의 해당 단계 설명을 다시 읽고, 빈칸 없이 처음부터 직접 입력해 보세요.
