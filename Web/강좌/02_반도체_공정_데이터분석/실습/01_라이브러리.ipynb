# %% [markdown]
# # 02 반도체 공정 데이터 분석 · 1. 라이브러리
#
# - 강의 페이지: `Web/강좌/02_반도체_공정_데이터분석/반도체_공정_데이터분석.html` → 목차 **라이브러리**
# - 분석에 필요한 라이브러리를 불러오고 설치 상태를 확인합니다.
# - 위에서 아래로 순서대로 실행하세요. 다른 노트북의 변수를 사용하지 않으므로 이 파일만 열어도 실행됩니다.

# %% [markdown]
# ### 3 코드로 직접 불러오기
# - 원본 코드: `01_import.py`
# - 설명: 분석에 필요한 라이브러리를 불러오고 짧은 별칭을 정합니다.

# %%
# 📦 분석에 사용할 라이브러리 불러오기
# 'as pd'는 앞으로 pandas를 pd라는 짧은 이름으로 부르겠다는 약속
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 그래프 한글 설정 (Mac은 'AppleGothic')
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False   # 음수(-) 기호 깨짐 방지

print("✅ 라이브러리 준비 완료!")

# %% [markdown]
# ## 마무리
#
# `✅ 라이브러리 준비 완료!`가 에러 없이 출력되면 성공입니다.
# `ModuleNotFoundError`가 나오면 `pip install pandas matplotlib seaborn`으로 설치한 뒤 다시 실행하세요.
